# %% [markdown]
# # Neural Network

# %% [markdown]
# ## Imports

# %%
import os
import random
import numpy as np
import pandas as pd
import joblib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score, confusion_matrix, classification_report, roc_auc_score
from sklearn.utils.class_weight import compute_class_weight

# %% [markdown]
# **Reproducibility**

# %%
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# %%
df = pd.read_csv("[CLEANED]supernova-dataset.csv")

# %% [markdown]
# ## Defining X and y

# %%
df = df[df["koi_disposition"] != "CANDIDATE"].copy()

df["target"] = (df["koi_disposition"] == "CONFIRMED").astype(int)

drop_cols = ["Unnamed: 0", "kepid", "koi_disposition"]
X = df.drop(columns=drop_cols + ["target"])
y = df["target"]

# %% [markdown]
# ## Train/Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=SEED
)

# %% [markdown]
# ## Scaling

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

os.makedirs("models", exist_ok=True)
joblib.dump(scaler, "models/nn_scaler.pkl")
# Out:
# ['models/nn_scaler.pkl']

# %% [markdown]
# ## Class weights

# %%
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_train),
    y=y_train
)

class_weights = dict(enumerate(class_weights))

# %% [markdown]
# ## Model Architecture

# %%
def build_model(input_dim):
    model = keras.Sequential([
        keras.Input(shape=(input_dim,)),  # <-- fix here

        layers.Dense(256, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(0.3),

        layers.Dense(128, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(0.3),

        layers.Dense(64, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(0.2),

        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=[keras.metrics.AUC(name="auc")]
    )

    return model

# %% [markdown]
# ## Early Stopping

# %%
early_stop = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)

# %% [markdown]
# ## Training

# %%
model = build_model(X_train.shape[1])

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=64,
    class_weight=class_weights,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - auc: 0.8339 - loss: 0.5231 - val_auc: 0.9421 - val_loss: 0.4329
# Epoch 2/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9237 - loss: 0.3574 - val_auc: 0.9495 - val_loss: 0.3645
# Epoch 3/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.9304 - loss: 0.3419 - val_auc: 0.9532 - val_loss: 0.3257
# Epoch 4/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.9404 - loss: 0.3135 - val_auc: 0.9563 - val_loss: 0.2940
# Epoch 5/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.9444 - loss: 0.3023 - val_auc: 0.9575 - val_loss: 0.2901
# Epoch 6/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9436 - loss: 0.3024 - val_auc: 0.9581 - val_loss: 0.2814
# Epoch 7/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9458 - loss: 0.2974 - val_auc: 0.9576 - val_loss: 0.2842
# Epoch 8/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9501 - loss: 0.2837 - val_auc: 0.9591 - val_loss: 0.2787
# Epoch 9/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9523 - loss: 0.2747 - val_auc: 0.9589 - val_loss: 0.2723
# Epoch 10/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9533 - loss: 0.2733 - val_auc: 0.9601 - val_loss: 0.2688
# Epoch 11/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9555 - loss: 0.2645 - val_auc: 0.9614 - val_loss: 0.2613
# Epoch 12/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9559 - loss: 0.2660 - val_auc: 0.9605 - val_loss: 0.2668
# Epoch 13/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9562 - loss: 0.2621 - val_auc: 0.9612 - val_loss: 0.2566
# Epoch 14/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9604 - loss: 0.2502 - val_auc: 0.9633 - val_loss: 0.2563
# Epoch 15/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9583 - loss: 0.2570 - val_auc: 0.9633 - val_loss: 0.2523
# Epoch 16/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9611 - loss: 0.2464 - val_auc: 0.9629 - val_loss: 0.2585
# Epoch 17/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9595 - loss: 0.2513 - val_auc: 0.9647 - val_loss: 0.2688
# Epoch 18/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9622 - loss: 0.2427 - val_auc: 0.9662 - val_loss: 0.2449
# Epoch 19/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9636 - loss: 0.2371 - val_auc: 0.9662 - val_loss: 0.2539
# Epoch 20/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9646 - loss: 0.2343 - val_auc: 0.9652 - val_loss: 0.2562
# Epoch 21/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9639 - loss: 0.2393 - val_auc: 0.9649 - val_loss: 0.2566
# Epoch 22/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9641 - loss: 0.2346 - val_auc: 0.9653 - val_loss: 0.2624
# Epoch 23/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.9675 - loss: 0.2240 - val_auc: 0.9655 - val_loss: 0.2546
# Epoch 24/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - auc: 0.9677 - loss: 0.2245 - val_auc: 0.9655 - val_loss: 0.2559
# Epoch 25/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.9681 - loss: 0.2222 - val_auc: 0.9650 - val_loss: 0.2499
# Epoch 26/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9685 - loss: 0.2198 - val_auc: 0.9668 - val_loss: 0.2503
# Epoch 27/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.9691 - loss: 0.2196 - val_auc: 0.9655 - val_loss: 0.2615
# Epoch 28/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.9717 - loss: 0.2092 - val_auc: 0.9674 - val_loss: 0.2467
